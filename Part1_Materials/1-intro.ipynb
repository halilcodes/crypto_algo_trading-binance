# %%
import os
import pandas as pd
import datetime as dt
from binance import Client, ThreadedWebsocketManager, ThreadedDepthCacheManager

# %%
public_key = os.getenv("binance_udemy_public_key")
secret_key = os.getenv("binance_udemy_secret_key")
testnet_api_public = "8a091c7b9a5cec1374dac77d19a7f6148ed36c8c52c518cb9a513c2dfbd1fe48"
testnet_api_secret = "4fd20c9e5982f78770ff3488f807f28a9430a1d69d9a6d8191e0ecf5f5dbf50d"

# %% [markdown]
# # getting client and exchange info

# %%
client = Client(api_key=public_key, api_secret=secret_key, tld="com")  # tld="com" for global
client.get_system_status()
# Out:
# {'status': 0, 'msg': 'normal'}

# %%
client.ping()
# Out:
# {}

# %%
account = client.get_account()
account
# Out:
# {'makerCommission': 10,
#  'takerCommission': 10,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'commissionRates': {'maker': '0.00100000',
#   'taker': '0.00100000',
#   'buyer': '0.00000000',
#   'seller': '0.00000000'},
#  'canTrade': True,
#  'canWithdraw': True,
#  'canDeposit': True,
#  'brokered': False,
#  'requireSelfTradePrevention': False,
#  'preventSor': False,
#  'updateTime': 1694917804219,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'BTC', 'free': '0.00151180', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNB', 'free': '0.00143559', 'locked': '0.00000000'},
#   {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
# ...

# %%
[i for i in client.get_trade_fee() if i['makerCommission'] == "0" and "BUSD" in i['symbol']]
# Out:
# [{'symbol': '1INCHBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AAVEBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ACABUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ACHBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ACMBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ADABUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'ADXBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AERGOBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AGIXBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AGLDBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AIONBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
#  {'symbol': 'AKROBUSD', 'makerCommission': '0', 'takerCommission': '0.001'},
# ...

# %%
df_fees = pd.DataFrame(client.get_trade_fee())
df_fees.sample(4)
# Out:
#        symbol makerCommission takerCommission
# 21    ACHUSDT           0.001           0.001
# 1079    IDBTC           0.001           0.001
# 1155   KEYETH           0.001           0.001
# 413    BSWETH           0.001           0.001

# %%
print(dt.datetime.fromtimestamp(account['updateTime']/1000))
print(pd.to_datetime(account['updateTime'], unit='ms'))
# Out:
# 2023-09-17 05:30:04.219000
# 2023-09-17 02:30:04.219000

# %%
df = pd.DataFrame(account['balances'])
df.head()
# Out:
#   asset        free      locked
# 0   BTC  0.00151180  0.00000000
# 1   LTC  0.00000000  0.00000000
# 2   ETH  0.00000000  0.00000000
# 3   NEO  0.00000000  0.00000000
# 4   BNB  0.00143559  0.00000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549 entries, 0 to 548
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   asset   549 non-null    object
#  1   free    549 non-null    object
#  2   locked  549 non-null    object
# dtypes: object(3)
# memory usage: 13.0+ KB

# %%
df.free = pd.to_numeric(df.free, errors="coerce")
df.locked = pd.to_numeric(df.locked, errors="coerce")

# %%
df.loc[df.free > 0]
# Out:
#      asset      free  locked
# 0      BTC  0.001512     0.0
# 4      BNB  0.001436     0.0
# 198  LDBTC  0.174687     0.0

# %%
client.get_asset_balance(asset='LDBTC')
# Out:
# {'asset': 'LDBTC', 'free': '0.17468664', 'locked': '0.00000000'}

# %%
client.get_all_orders(symbol='BTCUSDT')
# Out:
# []

# %%
client.get_account_snapshot(type='FUTURES')
# Out:
# {'code': 200,
#  'msg': '',
#  'snapshotVos': [{'type': 'futures',
#    'updateTime': 1694390399000,
#    'data': {'assets': [{'asset': 'BNB',
#       'marginBalance': '0',
#       'walletBalance': '0'},
#      {'asset': 'BTC', 'marginBalance': '0.00041', 'walletBalance': '0.00041'},
#      {'asset': 'USDT',
#       'marginBalance': '25.86242835',
#       'walletBalance': '25.86242835'}],
#     'position': [{'symbol': 'BTCUSDT',
#       'entryPrice': '0',
#       'markPrice': '25828.99938828',
#       'positionAmt': '0',
#       'unRealizedProfit': '0'},
#      {'symbol': 'LINKUSDT',
#       'entryPrice': '0',
#       'markPrice': '6.012',
#       'positionAmt': '0',
#       'unRealizedProfit': '0'},
#      {'symbol': 'SOLUSDT',
#       'entryPrice': '0',
#       'markPrice': '18.22553297',
#       'positionAmt': '0',
#       'unRealizedProfit': '0'},
#      {'symbol': 'LUNAUSDT',
#       'entryPrice': '0',
#       'positionAmt': '0',
#       'unRealizedProfit': '0'},
# ...

# %%
snap = pd.json_normalize(client.get_account_snapshot(type='FUTURES')['snapshotVos'])
snap.updateTime = pd.to_datetime(snap['updateTime'], unit="ms")
snap
# Out:
#       type          updateTime  \
# 0  futures 2023-09-10 23:59:59
# 1  futures 2023-09-11 23:59:59
# 2  futures 2023-09-12 23:59:59
# 3  futures 2023-09-13 23:59:59
# 4  futures 2023-09-14 23:59:59
# 5  futures 2023-09-15 23:59:59
# 6  futures 2023-09-16 23:59:59
#
#                                          data.assets  \
# 0  [{'asset': 'BNB', 'marginBalance': '0', 'walle...
# 1  [{'asset': 'BNB', 'marginBalance': '0', 'walle...
# 2  [{'asset': 'BNB', 'marginBalance': '0', 'walle...
# 3  [{'asset': 'BNB', 'marginBalance': '0', 'walle...
# 4  [{'asset': 'BNB', 'marginBalance': '0', 'walle...
# 5  [{'asset': 'BNB', 'marginBalance': '0', 'walle...
# 6  [{'asset': 'BNB', 'marginBalance': '0', 'walle...
#
#                                        data.position
# 0  [{'symbol': 'BTCUSDT', 'entryPrice': '0', 'mar...
# 1  [{'symbol': 'BTCUSDT', 'entryPrice': '0', 'mar...
# 2  [{'symbol': 'BTCUSDT', 'entryPrice': '0', 'mar...
# 3  [{'symbol': 'BTCUSDT', 'entryPrice': '0', 'mar...
# ...

# %%
snap['data.assets'][1]
# Out:
# [{'asset': 'BNB', 'marginBalance': '0', 'walletBalance': '0'},
#  {'asset': 'BTC', 'marginBalance': '0', 'walletBalance': '0'},
#  {'asset': 'USDT',
#   'marginBalance': '25.86242835',
#   'walletBalance': '25.86242835'}]

# %%
client.get_exchange_info()
# Out:
# {'timezone': 'UTC',
#  'serverTime': 1694941704519,
#  'rateLimits': [{'rateLimitType': 'REQUEST_WEIGHT',
#    'interval': 'MINUTE',
#    'intervalNum': 1,
#    'limit': 6000},
#   {'rateLimitType': 'ORDERS',
#    'interval': 'SECOND',
#    'intervalNum': 10,
#    'limit': 50},
#   {'rateLimitType': 'ORDERS',
#    'interval': 'DAY',
#    'intervalNum': 1,
#    'limit': 160000},
#   {'rateLimitType': 'RAW_REQUESTS',
#    'interval': 'MINUTE',
#    'intervalNum': 5,
#    'limit': 61000}],
#  'exchangeFilters': [],
#  'symbols': [{'symbol': 'ETHBTC',
#    'status': 'TRADING',
#    'baseAsset': 'ETH',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'quoteAssetPrecision': 8,
#    'baseCommissionPrecision': 8,
#    'quoteCommissionPrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
# ...

# %%
coins = pd.DataFrame(client.get_all_coins_info())
coins
# Out:
#           coin  depositAllEnable  withdrawAllEnable  \
# 0         AGLD              True               True
# 1          MXN              True               True
# 2         STPT              True              False
# 3          UGX              True               True
# 4          GLM              True               True
# ..         ...               ...                ...
# 510       AKRO              True               True
# 511       MOVR              True               True
# 512        XMR              True               True
# 513  1INCHDOWN             False              False
# 514       COTI              True               True
#
#                                name free locked freeze withdrawing ipoing  \
# 0                    Adventure Gold    0      0      0           0      0
# 1                      Mexican Peso    0      0      0           0      0
# 2    Standard Tokenization Protocol    0      0      0           0      0
# ...

# %%
client.get_trade_fee(symbol='BTCUSDT')
# Out:
# [{'symbol': 'BTCUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'}]

# %%
client.get_trade_fee(symbol='BUSDUSDT')
# Out:
# [{'symbol': 'BUSDUSDT', 'makerCommission': '0', 'takerCommission': '0'}]

# %%
client.get_symbol_info(symbol='BTCUSDT')
# Out:
# {'symbol': 'BTCUSDT',
#  'status': 'TRADING',
#  'baseAsset': 'BTC',
#  'baseAssetPrecision': 8,
#  'quoteAsset': 'USDT',
#  'quotePrecision': 8,
#  'quoteAssetPrecision': 8,
#  'baseCommissionPrecision': 8,
#  'quoteCommissionPrecision': 8,
#  'orderTypes': ['LIMIT',
#   'LIMIT_MAKER',
#   'MARKET',
#   'STOP_LOSS_LIMIT',
#   'TAKE_PROFIT_LIMIT'],
#  'icebergAllowed': True,
#  'ocoAllowed': True,
#  'quoteOrderQtyMarketAllowed': True,
#  'allowTrailingStop': True,
#  'cancelReplaceAllowed': True,
#  'isSpotTradingAllowed': True,
#  'isMarginTradingAllowed': True,
#  'filters': [{'filterType': 'PRICE_FILTER',
#    'minPrice': '0.01000000',
#    'maxPrice': '1000000.00000000',
#    'tickSize': '0.01000000'},
#   {'filterType': 'LOT_SIZE',
#    'minQty': '0.00001000',
#    'maxQty': '9000.00000000',
#    'stepSize': '0.00001000'},
#   {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#   {'filterType': 'MARKET_LOT_SIZE',
#    'minQty': '0.00000000',
#    'maxQty': '197.18180686',
# ...

# %% [markdown]
# # Getting (current) market data

# %% [markdown]
# ## Current prices

# %%
client.get_symbol_ticker(symbol='LINKUSDT')
# Out:
# {'symbol': 'LINKUSDT', 'price': '6.20700000'}

# %%
client.get_avg_price(symbol='LINKUSDT')
# Out:
# {'mins': 5, 'price': '6.21088023'}

# %%
prices = client.get_all_tickers()
prices
# Out:
# [{'symbol': 'ETHBTC', 'price': '0.06144000'},
#  {'symbol': 'LTCBTC', 'price': '0.00241400'},
#  {'symbol': 'BNBBTC', 'price': '0.00809100'},
#  {'symbol': 'NEOBTC', 'price': '0.00027210'},
#  {'symbol': 'QTUMETH', 'price': '0.00132100'},
#  {'symbol': 'EOSETH', 'price': '0.00034840'},
#  {'symbol': 'SNTETH', 'price': '0.00001345'},
#  {'symbol': 'BNTETH', 'price': '0.00025660'},
#  {'symbol': 'BCCBTC', 'price': '0.07908100'},
#  {'symbol': 'GASBTC', 'price': '0.00008910'},
#  {'symbol': 'BNBETH', 'price': '0.13170000'},
#  {'symbol': 'BTCUSDT', 'price': '26555.48000000'},
#  {'symbol': 'ETHUSDT', 'price': '1631.30000000'},
#  {'symbol': 'HSRBTC', 'price': '0.00041400'},
#  {'symbol': 'OAXETH', 'price': '0.00017780'},
#  {'symbol': 'DNTETH', 'price': '0.00002801'},
#  {'symbol': 'MCOETH', 'price': '0.00577200'},
#  {'symbol': 'ICNETH', 'price': '0.00166300'},
#  {'symbol': 'MCOBTC', 'price': '0.00021140'},
#  {'symbol': 'WTCBTC', 'price': '0.00000574'},
# ...

# %%
df = pd.DataFrame(prices)
df
# Out:
#          symbol         price
# 0        ETHBTC    0.06144000
# 1        LTCBTC    0.00241400
# 2        BNBBTC    0.00809100
# 3        NEOBTC    0.00027210
# 4       QTUMETH    0.00132100
# ...         ...           ...
# 2290   SOLFDUSD   18.96000000
# 2291    TOMOTRY   32.24000000
# 2292    UNFITRY  211.20000000
# 2293   XRPFDUSD    0.49620000
# 2294  DOGEFDUSD    0.06222000
#
# [2295 rows x 2 columns]

# %%
df.loc[df['symbol'].str.endswith('USDT')]
# Out:
#          symbol           price
# 11      BTCUSDT  26555.48000000
# 12      ETHUSDT   1631.30000000
# 98      BNBUSDT    214.90000000
# 125     BCCUSDT    448.70000000
# 141     NEOUSDT      7.23000000
# ...         ...             ...
# 2251  WBETHUSDT   1658.40000000
# 2258    WLDUSDT      1.36000000
# 2262  FDUSDUSDT      0.99960000
# 2280    SEIUSDT      0.12820000
# 2285  CYBERUSDT      5.00600000
#
# [457 rows x 2 columns]

# %%
last24 = client.get_ticker(symbol='LINKUSDT')
last24
# Out:
# {'symbol': 'LINKUSDT',
#  'priceChange': '-0.06900000',
#  'priceChangePercent': '-1.099',
#  'weightedAvgPrice': '6.23656595',
#  'prevClosePrice': '6.27500000',
#  'lastPrice': '6.20700000',
#  'lastQty': '4.82000000',
#  'bidPrice': '6.20700000',
#  'bidQty': '16.11000000',
#  'askPrice': '6.20800000',
#  'askQty': '1576.03000000',
#  'openPrice': '6.27600000',
#  'highPrice': '6.29700000',
#  'lowPrice': '6.17100000',
#  'volume': '1455724.53000000',
#  'quoteVolume': '9078722.03364000',
#  'openTime': 1694855302740,
#  'closeTime': 1694941702740,
#  'firstId': 265393051,
#  'lastId': 265422400,
#  'count': 29350}

# %% [markdown]
# # load historical data (ohlc & volume)

# %%
timestamp = client._get_earliest_valid_timestamp(symbol = "BTCUSDT", interval = "1d")
timestamp
# Out:
# 1502928000000

# %%
dt.datetime.fromtimestamp(timestamp/1000)
# Out:
# datetime.datetime(2017, 8, 17, 3, 0)

# %%
pd.to_datetime(timestamp, unit='ms')
# Out:
# Timestamp('2017-08-17 00:00:00')

# %%
bars = client.get_historical_klines(symbol="BTCUSDT", interval="1h", start_str=timestamp)
bars
# Out:
# [[1502942400000,
#   '4261.48000000',
#   '4313.62000000',
#   '4261.32000000',
#   '4308.83000000',
#   '47.18100900',
#   1502945999999,
#   '202366.13839304',
#   171,
#   '35.16050300',
#   '150952.47794304',
#   '0'],
#  [1502946000000,
#   '4308.83000000',
#   '4328.69000000',
#   '4291.37000000',
#   '4315.32000000',
#   '23.23491600',
#   1502949599999,
#   '100304.82356749',
#   102,
#   '21.44807100',
#   '92608.27972836',
#   '0'],
#  [1502949600000,
#   '4330.29000000',
#   '4345.45000000',
#   '4309.37000000',
#   '4324.35000000',
#   '7.22969100',
#   1502953199999,
#   '31282.31266989',
#   36,
#   '4.80286100',
#   '20795.31722405',
#   '0'],
#  [1502953200000,
#   '4316.62000000',
#   '4349.99000000',
#   '4287.41000000',
#   '4349.99000000',
#   '4.44324900',
#   1502956799999,
#   '19241.05829986',
#   25,
#   '2.60229200',
#   '11291.34701534',
#   '0'],
#  [1502956800000,
#   '4333.32000000',
#   '4377.85000000',
#   '4333.32000000',
#   '4360.69000000',
# ...

# %%
len(bars)
# Out:
# 53206

# %%
df = pd.DataFrame(bars)
df
# Out:
#                   0               1               2               3   \
# 0      1502942400000   4261.48000000   4313.62000000   4261.32000000
# 1      1502946000000   4308.83000000   4328.69000000   4291.37000000
# 2      1502949600000   4330.29000000   4345.45000000   4309.37000000
# 3      1502953200000   4316.62000000   4349.99000000   4287.41000000
# 4      1502956800000   4333.32000000   4377.85000000   4333.32000000
# ...              ...             ...             ...             ...
# 53201  1694926800000  26552.85000000  26560.00000000  26520.00000000
# 53202  1694930400000  26543.79000000  26545.98000000  26524.37000000
# 53203  1694934000000  26545.42000000  26547.37000000  26490.88000000
# 53204  1694937600000  26495.94000000  26553.99000000  26493.13000000
# 53205  1694941200000  26551.15000000  26567.00000000  26545.71000000
#
#                    4             5              6                  7      8   \
# ...

# %%
df[0] = pd.to_datetime(df[0], unit='ms')

# %%
df.columns = ["Open Time", "Open", "High", "Low", "Close",
              "Volume", "Close Time", "Quote Asset Volume", 
              "Number of Trades", "Taker Buy Base Asset Volume",
              "Taker Buy Quote Asset Volume", "Ignore"]

# %%
df["Close Time"] = pd.to_datetime(df["Close Time"], unit='ms')
df.sample(5)
# Out:
#                 Open Time            Open            High             Low  \
# 42773 2022-07-09 16:00:00  21545.89000000  21718.34000000  21530.32000000
# 41063 2022-04-29 10:00:00  39147.86000000  39243.54000000  38666.10000000
# 32525 2021-05-08 10:00:00  58800.00000000  58888.00000000  58305.00000000
# 23006 2020-04-06 01:00:00   6866.59000000   6888.00000000   6829.44000000
# 44676 2022-09-26 23:00:00  19138.41000000  19246.33000000  19113.01000000
#
#                 Close          Volume              Close Time  \
# 42773  21693.15000000   6634.94020000 2022-07-09 16:59:59.999
# 41063  38805.41000000   2926.26292000 2022-04-29 10:59:59.999
# 32525  58539.56000000   2303.58396100 2021-05-08 10:59:59.999
# 23006   6841.36000000   2957.52059700 2020-04-06 01:59:59.999
# 44676  19227.82000000  13514.06311000 2022-09-26 23:59:59.999
#
#        Quote Asset Volume  Number of Trades Taker Buy Base Asset Volume  \
# ...
